# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sms

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/COVID19India.csv')

# %%
df
# Out:
#                 Date    Date_YMD  Daily Confirmed  Daily Deceased
# 0    30 January 2020  2020-01-30                1               0
# 1    31 January 2020  2020-01-31                0               0
# 2    1 February 2020  2020-02-01                0               0
# 3    2 February 2020  2020-02-02                1               0
# 4    3 February 2020  2020-02-03                1               0
# ..               ...         ...              ...             ...
# 715  14 January 2022  2022-01-14           266518             621
# 716  15 January 2022  2022-01-15           271202             314
# 717  16 January 2022  2022-01-16           258089             385
# 718  17 January 2022  2022-01-17           238018             310
# 719  18 January 2022  2022-01-18           282970             441
#
# [720 rows x 4 columns]

# %%
df.head()
# Out:
#               Date    Date_YMD  Daily Confirmed  Daily Deceased
# 0  30 January 2020  2020-01-30                1               0
# 1  31 January 2020  2020-01-31                0               0
# 2  1 February 2020  2020-02-01                0               0
# 3  2 February 2020  2020-02-02                1               0
# 4  3 February 2020  2020-02-03                1               0

# %%
df.tail()
# Out:
#                 Date    Date_YMD  Daily Confirmed  Daily Deceased
# 715  14 January 2022  2022-01-14           266518             621
# 716  15 January 2022  2022-01-15           271202             314
# 717  16 January 2022  2022-01-16           258089             385
# 718  17 January 2022  2022-01-17           238018             310
# 719  18 January 2022  2022-01-18           282970             441

# %%
df.head(10)
# Out:
#               Date    Date_YMD  Daily Confirmed  Daily Deceased
# 0  30 January 2020  2020-01-30                1               0
# 1  31 January 2020  2020-01-31                0               0
# 2  1 February 2020  2020-02-01                0               0
# 3  2 February 2020  2020-02-02                1               0
# 4  3 February 2020  2020-02-03                1               0
# 5  4 February 2020  2020-02-04                0               0
# 6  5 February 2020  2020-02-05                0               0
# 7  6 February 2020  2020-02-06                0               0
# 8  7 February 2020  2020-02-07                0               0
# 9  8 February 2020  2020-02-08                0               0

# %%
df.tail(10)
# Out:
#                 Date    Date_YMD  Daily Confirmed  Daily Deceased
# 710   9 January 2022  2022-01-09           179123             146
# 711  10 January 2022  2022-01-10           168063             277
# 712  11 January 2022  2022-01-11           221068             411
# 713  12 January 2022  2022-01-12           221069             411
# 714  13 January 2022  2022-01-13           266517              96
# 715  14 January 2022  2022-01-14           266518             621
# 716  15 January 2022  2022-01-15           271202             314
# 717  16 January 2022  2022-01-16           258089             385
# 718  17 January 2022  2022-01-17           238018             310
# 719  18 January 2022  2022-01-18           282970             441

# %%
df.shape
# Out:
# (720, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             720 non-null    object
#  1   Date_YMD         720 non-null    object
#  2   Daily Confirmed  720 non-null    int64
#  3   Daily Deceased   720 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 22.6+ KB

# %%
df.describe()
# Out:
#        Daily Confirmed  Daily Deceased
# count       720.000000      720.000000
# mean      52637.915278      675.901389
# std       78522.746943      932.895333
# min           0.000000        0.000000
# 25%       10419.250000      159.000000
# 50%       27383.000000      387.000000
# 75%       54300.750000      734.750000
# max      414280.000000     6139.000000

# %%
df.isnull()
# Out:
#       Date  Date_YMD  Daily Confirmed  Daily Deceased
# 0    False     False            False           False
# 1    False     False            False           False
# 2    False     False            False           False
# 3    False     False            False           False
# 4    False     False            False           False
# ..     ...       ...              ...             ...
# 715  False     False            False           False
# 716  False     False            False           False
# 717  False     False            False           False
# 718  False     False            False           False
# 719  False     False            False           False
#
# [720 rows x 4 columns]

# %%
# !pip install missingno

# %%
import missingno as ms

# %%
ms.bar(df)
# Out:
# <AxesSubplot:>

# %%
ms.heatmap(df)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\matrix.py:305: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\matrix.py:305: UserWarning: Attempting to set identical bottom == top == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# <AxesSubplot:>

# %%
ms.matrix(df)
# Out:
# <AxesSubplot:>

# %%
ms.dendrogram(df)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\scipy\cluster\hierarchy.py:2844: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   ax.set_ylim([dvw, 0])
# <AxesSubplot:>

# %%
sms.distplot(df["Daily Deceased"])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Daily Deceased', ylabel='Density'>

# %%
sms.distplot(df["Daily Confirmed"])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Daily Confirmed', ylabel='Density'>

# %%
sms.distplot(df["Daily Confirmed"],hist = False)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Daily Confirmed', ylabel='Density'>

# %%
sms.distplot(df["Daily Deceased"],hist = False)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Daily Deceased', ylabel='Density'>

# %%
sms.distplot(df["Daily Deceased"],hist_kws=dict(linewidth =2,color="r", edgecolor = 'g'))
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Daily Deceased', ylabel='Density'>

# %%
sms.distplot(df["Daily Confirmed"],hist_kws=dict(linewidth =2,color="y"))
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Daily Confirmed', ylabel='Density'>

# %%
sms.set_style("whitegrid")

# %%
sms.distplot(df["Daily Confirmed"],hist_kws=dict(linewidth =2,edgecolor="y"))
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Daily Confirmed', ylabel='Density'>

# %%
sms.distplot(df["Daily Confirmed"],hist=False)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Daily Confirmed', ylabel='Density'>

# %%
sms.distplot(df["Daily Confirmed"],hist=False)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Daily Confirmed', ylabel='Density'>

# %%
x,y = plt.subplots(figsize =(8,8))
sms.distplot(df["Daily Confirmed"],hist = False,ax = y)
y.axvline(df["Daily Confirmed"].mean(),color="r",ls="--");
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
x,y = plt.subplots(figsize =(8,8))
sms.distplot(df["Daily Deceased"],hist = False,ax = y)
y.axvline(df["Daily Deceased"].mean(),color="y",ls="--");
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
unique =[]
for i in df.columns:
    x = df[i].value_counts().count()
    unique.append(x)
    
pd.DataFrame(unique, index = df.columns, columns = ["total unique values"])
# Out:
#                  total unique values
# Date                             720
# Date_YMD                         720
# Daily Confirmed                  684
# Daily Deceased                   509

# %%
import seaborn as sms
correlation = df.drop(['Daily Deceased'],axis=1).corr()
plt.figure(figsize=(10, 10))
sms.heatmap(correlation, annot=True)
plt.show()

# %%
import seaborn as sms
correlation = df.drop(['Daily Confirmed'],axis=1).corr()
plt.figure(figsize=(10, 10))
sms.heatmap(correlation, annot=True)
plt.show()

# %%
numerical = ["Daily Confirmed", "Daily Deceased"]
numerical_axis = ["Daily Deceased", "Daily Confirmed"]

# %%
data = list(zip(numerical,numerical_axis))

# %%
title_font ={"family":"arial","color":"darkred","weight":"bold","size":15}
axis_font ={"family":"arial","color":"darkgreen","weight":"bold","size":10}

for i,z in list(zip(numerical,numerical_axis)):
    plt.figure(figsize=(5,5),dpi=90)
    sms.distplot(df[i], hist_kws = dict(linewidth=1,edgecolor = 'r'))
    
    plt.title(i, fontdict = title_font)
    plt.xlabel(z, fontdict = axis_font)
    plt.ylabel("Density", fontdict = axis_font)
    
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
